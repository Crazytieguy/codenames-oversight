# %%
from codenames_debate.models import EvaluationPair
from pathlib import Path

data_file = Path("data/dpo-3-dataset.jsonl")
pairs = [EvaluationPair.model_validate_json(line) for line in data_file.read_text().splitlines()]

# %%
import pandas as pd

# %%
s = pd.Series([e.reward for p in pairs for e in p.evaluations])

# %%
xticks = [n / 5 for n in range(-5, 10)]
ax = s.hist(bins=xticks)
ax.set_xticks(xticks)
ax
# Out:
# <Axes: >

# %%
s.mean()
# Out:
# 0.25637207031250003
