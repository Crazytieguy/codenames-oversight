# %%
import pandas as pd

df = pd.read_csv("results/oracle-grouped-with-mistakes.csv")

# %%
df['mean_exploitation'] = df.mean_expected_score / df.mean_ground_truth_score
df['overseer_accuracy'] = 1 - df.overseer_mistakes

# %%
import matplotlib.pyplot as plt

consultancy_canonical = df[:10]
consultancy_underweigh_non_neglected = df[10:20]
consultancy_slight_underweigh_non_neglected = df[20:30]
consultancy_slight_overweigh_non_neglected = df[30:40]
consultancy_overweigh_non_neglected = df[40:50]
consultancy_neglect = df[50:60]
consultancy_neglect_underweigh_non_neglected = df[60:70]
consultancy_neglect_slight_underweigh_non_neglected = df[70:80]
consultancy_neglect_slight_overweigh_non_neglected = df[80:90]
consultancy_neglect_overweigh_non_neglected = df[90:100]
consultancy_neglect_underweigh_neglected = df[100:110]
consultancy_neglect_slight_underweigh_neglected = df[110:120]
consultancy_neglect_slight_overweigh_neglected = df[120:130]
consultancy_neglect_overweigh_neglected = df[130:140]
consultancy_neglect_underweigh_both = df[140:150]
consultancy_neglect_slight_underweigh_both = df[150:160]
consultancy_neglect_slight_overweigh_both = df[160:170]
consultancy_neglect_overweigh_both = df[170:180]
critiques_canonical = df[180:190]
critiques_underweigh_non_neglected = df[190:200]
critiques_slight_underweigh_non_neglected = df[200:210]
critiques_slight_overweigh_non_neglected = df[210:220]
critiques_overweigh_non_neglected = df[220:230]
critiques_neglect = df[230:240]
critiques_neglect_underweigh_non_neglected = df[240:250]
critiques_neglect_slight_underweigh_non_neglected = df[250:260]
critiques_neglect_slight_overweigh_non_neglected = df[260:270]
critiques_neglect_overweigh_non_neglected = df[270:280]
critiques_neglect_underweigh_neglected = df[280:290]
critiques_neglect_slight_underweigh_neglected = df[290:300]
critiques_neglect_slight_overweigh_neglected = df[300:310]
critiques_neglect_overweigh_neglected = df[310:320]
critiques_neglect_underweigh_both = df[320:330]
critiques_neglect_slight_underweigh_both = df[330:340]
critiques_neglect_slight_overweigh_both = df[340:350]
critiques_neglect_overweigh_both = df[350:360]

all_overseers = [
    consultancy_canonical,
    consultancy_underweigh_non_neglected,
    consultancy_slight_underweigh_non_neglected,
    consultancy_slight_overweigh_non_neglected,
    consultancy_overweigh_non_neglected,
    consultancy_neglect,
    consultancy_neglect_underweigh_non_neglected,
    consultancy_neglect_slight_underweigh_non_neglected,
    consultancy_neglect_slight_overweigh_non_neglected,
    consultancy_neglect_overweigh_non_neglected,
    consultancy_neglect_underweigh_neglected,
    consultancy_neglect_slight_underweigh_neglected,
    consultancy_neglect_slight_overweigh_neglected,
    consultancy_neglect_overweigh_neglected,
    consultancy_neglect_underweigh_both,
    consultancy_neglect_slight_underweigh_both,
    consultancy_neglect_slight_overweigh_both,
    consultancy_neglect_overweigh_both,
    critiques_canonical,
    critiques_underweigh_non_neglected,
    critiques_slight_underweigh_non_neglected,
    critiques_slight_overweigh_non_neglected,
    critiques_overweigh_non_neglected,
    critiques_neglect,
    critiques_neglect_underweigh_non_neglected,
    critiques_neglect_slight_underweigh_non_neglected,
    critiques_neglect_slight_overweigh_non_neglected,
    critiques_neglect_overweigh_non_neglected,
    critiques_neglect_underweigh_neglected,
    critiques_neglect_slight_underweigh_neglected,
    critiques_neglect_slight_overweigh_neglected,
    critiques_neglect_overweigh_neglected,
    critiques_neglect_underweigh_both,
    critiques_neglect_slight_underweigh_both,
    critiques_neglect_slight_overweigh_both,
    critiques_neglect_overweigh_both,
]

interesting_overseers = [
    consultancy_canonical,
    consultancy_underweigh_non_neglected,
    consultancy_overweigh_non_neglected,
    consultancy_neglect,
    consultancy_neglect_underweigh_both,
    consultancy_neglect_overweigh_both,
    critiques_canonical,
    critiques_underweigh_non_neglected,
    critiques_overweigh_non_neglected,
    critiques_neglect,
    critiques_neglect_underweigh_both,
    critiques_neglect_overweigh_both,
]

consultancy_canonical.name = 'Consultancy canonical'
consultancy_underweigh_non_neglected.name = 'Consultancy underweigh non-neglected'
consultancy_slight_underweigh_non_neglected.name = 'Consultancy slight underweigh non-neglected'
consultancy_slight_overweigh_non_neglected.name = 'Consultancy slight overweigh non-neglected'
consultancy_overweigh_non_neglected.name = 'Consultancy overweigh non-neglected'
consultancy_neglect.name = 'Consultancy neglect'
consultancy_neglect_underweigh_non_neglected.name = 'Consultancy neglect underweigh non-neglected'
consultancy_neglect_slight_underweigh_non_neglected.name = 'Consultancy neglect slight underweigh non-neglected'
consultancy_neglect_slight_overweigh_non_neglected.name = 'Consultancy neglect slight overweigh non-neglected'
consultancy_neglect_overweigh_non_neglected.name = 'Consultancy neglect overweigh non-neglected'
consultancy_neglect_underweigh_neglected.name = 'Consultancy neglect underweigh neglected'
consultancy_neglect_slight_underweigh_neglected.name = 'Consultancy neglect slight underweigh neglected'
consultancy_neglect_slight_overweigh_neglected.name = 'Consultancy neglect slight overweigh neglected'
consultancy_neglect_overweigh_neglected.name = 'Consultancy neglect overweigh neglected'
consultancy_neglect_underweigh_both.name = 'Consultancy neglect underweigh both'
consultancy_neglect_slight_underweigh_both.name = 'Consultancy neglect slight underweigh both'
consultancy_neglect_slight_overweigh_both.name = 'Consultancy neglect slight overweigh both'
consultancy_neglect_overweigh_both.name = 'Consultancy neglect overweigh both'
critiques_canonical.name = 'Critiques canonical'
critiques_underweigh_non_neglected.name = 'Critiques underweigh non-neglected'
critiques_slight_underweigh_non_neglected.name = 'Critiques slight underweigh non-neglected'
critiques_slight_overweigh_non_neglected.name = 'Critiques slight overweigh non-neglected'
critiques_overweigh_non_neglected.name = 'Critiques overweigh non-neglected'
critiques_neglect.name = 'Critiques neglect'
critiques_neglect_underweigh_non_neglected.name = 'Critiques neglect underweigh non-neglected'
critiques_neglect_slight_underweigh_non_neglected.name = 'Critiques neglect slight underweigh non-neglected'
critiques_neglect_slight_overweigh_non_neglected.name = 'Critiques neglect slight overweigh non-neglected'
critiques_neglect_overweigh_non_neglected.name = 'Critiques neglect overweigh non-neglected'
critiques_neglect_underweigh_neglected.name = 'Critiques neglect underweigh neglected'
critiques_neglect_slight_underweigh_neglected.name = 'Critiques neglect slight underweigh neglected'
critiques_neglect_slight_overweigh_neglected.name = 'Critiques neglect slight overweigh neglected'
critiques_neglect_overweigh_neglected.name = 'Critiques neglect overweigh neglected'
critiques_neglect_underweigh_both.name = 'Critiques neglect underweigh both'
critiques_neglect_slight_underweigh_both.name = 'Critiques neglect slight underweigh both'
critiques_neglect_slight_overweigh_both.name = 'Critiques neglect slight overweigh both'
critiques_neglect_overweigh_both.name = 'Critiques neglect overweigh both'

fig, consultancy_ax = plt.subplots()

for overseer in interesting_overseers:
    consultancy_ax.plot(overseer.adversarial_alpha, overseer.mean_exploitation, label=overseer.name)
consultancy_ax.set_xlabel('Adversarial incentive')
consultancy_ax.set_ylabel('Mean exploitation')
consultancy_ax.set_title('Mean exploitation vs. adversarial incentive')
fig.legend()
fig.tight_layout()

# %%
fig, consultancy_ax = plt.subplots()
colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan', 'magenta', 'yellow', 'black', 'teal', 'coral', 'lightblue', 'lightgreen', 'lavender', 'salmon', 'darkred']
for overseer, color in zip(interesting_overseers, colors):
    consultancy_ax.plot(overseer.adversarial_alpha, overseer.mean_expected_score, label=None, color=color, linestyle='--')
    consultancy_ax.plot(overseer.adversarial_alpha, overseer.mean_ground_truth_score, label=overseer.name, color=color)
    # ax.plot(overseer.adversarial_alpha, canonical.mean_expected_score, label='Canonical', linestyle='--')
    consultancy_ax.set_xlabel('Adversarial incentive')
    consultancy_ax.set_ylabel('Mean score')
    consultancy_ax.set_title(f'Mean score vs. adversarial incentive ({overseer.name})')

fig.legend(loc='lower left', bbox_to_anchor=(0.09, 0.13))
fig.tight_layout()

# %%
from matplotlib.ticker import FuncFormatter

def percentage_formatter(x, pos):
    return f'{100 * x:.0f}%'

percent_formatter = FuncFormatter(percentage_formatter)

fig, axs = plt.subplots(4, 2, figsize=(10, 15))

twins = []

axs[0, 0].plot(consultancy_neglect.adversarial_alpha, consultancy_neglect.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[0, 0].twinx()
twin.plot(consultancy_neglect.adversarial_alpha, consultancy_neglect.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[0, 1].plot(critiques_neglect.adversarial_alpha, critiques_neglect.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[0, 1].twinx()
twin.plot(critiques_neglect.adversarial_alpha, critiques_neglect.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[1, 0].plot(consultancy_underweigh_non_neglected.adversarial_alpha, consultancy_underweigh_non_neglected.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[1, 0].twinx()
twin.plot(consultancy_underweigh_non_neglected.adversarial_alpha, consultancy_underweigh_non_neglected.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[1, 1].plot(critiques_underweigh_non_neglected.adversarial_alpha, critiques_underweigh_non_neglected.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[1, 1].twinx()
twin.plot(critiques_underweigh_non_neglected.adversarial_alpha, critiques_underweigh_non_neglected.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[2, 0].plot(consultancy_overweigh_non_neglected.adversarial_alpha, consultancy_overweigh_non_neglected.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[2, 0].twinx()
twin.plot(consultancy_overweigh_non_neglected.adversarial_alpha, consultancy_overweigh_non_neglected.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[2, 1].plot(critiques_overweigh_non_neglected.adversarial_alpha, critiques_overweigh_non_neglected.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[2, 1].twinx()
twin.plot(critiques_overweigh_non_neglected.adversarial_alpha, critiques_overweigh_non_neglected.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[3, 0].plot(consultancy_neglect_overweigh_both.adversarial_alpha, consultancy_neglect_overweigh_both.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[3, 0].twinx()
twin.plot(consultancy_neglect_overweigh_both.adversarial_alpha, consultancy_neglect_overweigh_both.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[3, 1].plot(critiques_neglect_overweigh_both.adversarial_alpha, critiques_neglect_overweigh_both.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[3, 1].twinx()
twin.plot(critiques_neglect_overweigh_both.adversarial_alpha, critiques_neglect_overweigh_both.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

for ax in axs.flat:
    ax.yaxis.set_major_formatter(percent_formatter)
    ax.set_ylim(0, 1.1)
    ax.set_ylabel('Overseer Accuracy', color='blue')
    ax.tick_params(axis='y', labelcolor='blue')
    ax.set_xlabel('Adversarial incentive')

for twin in twins:
    twin.set_ylim(1, 8)
    twin.set_ylabel('Mean True Score', color='orange')
    twin.tick_params(axis='y', labelcolor='orange')

# Set column titles
fig.text(0.33, 0.94, 'Consultancy', ha='center', va='center', fontsize=12, fontweight='bold')
fig.text(0.77, 0.94, 'Critiques', ha='center', va='center', fontsize=12, fontweight='bold')

# Set row titles
fig.text(0.07, 0.84, 'Neglect', ha='center', va='center', rotation='vertical', fontsize=12, fontweight='bold')
fig.text(0.07, 0.60, 'Underweigh', ha='center', va='center', rotation='vertical', fontsize=12, fontweight='bold')
fig.text(0.07, 0.37, 'Overweigh', ha='center', va='center', rotation='vertical', fontsize=12, fontweight='bold')
fig.text(0.07, 0.13, 'Neglect + Double Overweigh', ha='center', va='center', rotation='vertical', fontsize=12, fontweight='bold')

# Adjust layout and display the plot
fig.tight_layout(rect=(0.08, 0.0, 1.0, 0.94))

# %%
from pathlib import Path
from codenames_oversight.oversight import PreferenceSet

ppo_data = [PreferenceSet.model_validate_json(line).oversights[0].model_dump() for line in Path("job_outputs/codenames_oversight_ppo_small_robust_init_ratio/48875882_7.out").read_text().splitlines()]

ppo_df = pd.DataFrame(ppo_data)

fig, consultancy_ax = plt.subplots()
consultancy_ax.plot(ppo_df.expected_score.rolling(window=512).mean(), label='Overseer')
consultancy_ax.plot(ppo_df.ground_truth_score.rolling(window=512).mean(), label='Ground truth')
consultancy_ax.plot(ppo_df.valid_targets.apply(len).rolling(window=512).mean(), label='N targets', linestyle='--')
consultancy_ax.set_xlabel('Sample')
consultancy_ax.set_ylabel('Score')
consultancy_ax.set_title('Score vs. sample (smoothed)')
fig.legend()
fig.tight_layout()

# %%
consultancy_neglect
# Out:
#       overseer__name  overseer__neglect_words  overseer__bias_neglected_words  \
# 50  negligent_biased                        1                               0
# 51  negligent_biased                        1                               0
# 52  negligent_biased                        1                               0
# 53  negligent_biased                        1                               0
# 54  negligent_biased                        1                               0
# 55  negligent_biased                        1                               0
# 56  negligent_biased                        1                               0
# 57  negligent_biased                        1                               0
# 58  negligent_biased                        1                               0
# 59  negligent_biased                        1                               0
#
#     overseer__bias_non_neglected_words  overseer__bias_factor  \
# ...
