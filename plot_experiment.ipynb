# %%
import pandas as pd

df = pd.read_csv("results/oracle-2048-words-with-neglect-good.csv")

# %%
df['mean_exploitation'] = df.mean_expected_score / df.mean_ground_truth_score
df['overseer_accuracy'] = 1 - df.overseer_mistakes

# %%
import matplotlib.pyplot as plt

consultancy_canonical = df[:10]
consultancy_neglect_good = df[10:20]
consultancy_underweigh_non_neglected = df[20:30]
consultancy_underweigh_non_neglected_neglect_good = df[30:40]
consultancy_overweigh_non_neglected = df[40:50]
consultancy_overweigh_non_neglected_neglect_good = df[50:60]
consultancy_neglect = df[60:70]
consultancy_neglect_neglect_good = df[70:80]
consultancy_neglect_underweigh_non_neglected = df[80:90]
consultancy_neglect_underweigh_non_neglected_neglect_good = df[90:100]
consultancy_neglect_overweigh_non_neglected = df[100:110]
consultancy_neglect_overweigh_non_neglected_neglect_good = df[110:120]
consultancy_neglect_underweigh_neglected = df[120:130]
consultancy_neglect_underweigh_neglected_neglect_good = df[130:140]
consultancy_neglect_overweigh_neglected = df[140:150]
consultancy_neglect_overweigh_neglected_neglect_good = df[150:160]
consultancy_neglect_underweigh_both = df[160:170]
consultancy_neglect_underweigh_both_neglect_good = df[170:180]
consultancy_neglect_overweigh_both = df[180:190]
consultancy_neglect_overweigh_both_neglect_good = df[190:200]
base_canonical = df[200:210]
base_neglect_good = df[210:220]
base_underweigh_non_neglected = df[220:230]
base_underweigh_non_neglected_neglect_good = df[230:240]
base_overweigh_non_neglected = df[240:250]
base_overweigh_non_neglected_neglect_good = df[250:260]
base_neglect = df[260:270]
base_neglect_neglect_good = df[270:280]
base_neglect_underweigh_non_neglected = df[280:290]
base_neglect_underweigh_non_neglected_neglect_good = df[290:300]
base_neglect_overweigh_non_neglected = df[300:310]
base_neglect_overweigh_non_neglected_neglect_good = df[310:320]
base_neglect_underweigh_neglected = df[320:330]
base_neglect_underweigh_neglected_neglect_good = df[330:340]
base_neglect_overweigh_neglected = df[340:350]
base_neglect_overweigh_neglected_neglect_good = df[350:360]
base_neglect_underweigh_both = df[360:370]
base_neglect_underweigh_both_neglect_good = df[370:380]
base_neglect_overweigh_both = df[380:390]
base_neglect_overweigh_both_neglect_good = df[390:400]
critiques_canonical = df[400:410]
critiques_neglect_good = df[410:420]
critiques_underweigh_non_neglected = df[420:430]
critiques_underweigh_non_neglected_neglect_good = df[430:440]
critiques_overweigh_non_neglected = df[440:450]
critiques_overweigh_non_neglected_neglect_good = df[450:460]
critiques_neglect = df[460:470]
critiques_neglect_neglect_good = df[470:480]
critiques_neglect_underweigh_non_neglected = df[480:490]
critiques_neglect_underweigh_non_neglected_neglect_good = df[490:500]
critiques_neglect_overweigh_non_neglected = df[500:510]
critiques_neglect_overweigh_non_neglected_neglect_good = df[510:520]
critiques_neglect_underweigh_neglected = df[520:530]
critiques_neglect_underweigh_neglected_neglect_good = df[530:540]
critiques_neglect_overweigh_neglected = df[540:550]
critiques_neglect_overweigh_neglected_neglect_good = df[550:560]
critiques_neglect_underweigh_both = df[560:570]
critiques_neglect_underweigh_both_neglect_good = df[570:580]
critiques_neglect_overweigh_both = df[580:590]
critiques_neglect_overweigh_both_neglect_good = df[590:600]


all_overseers = [
    consultancy_canonical,
    consultancy_neglect_good,
    consultancy_underweigh_non_neglected,
    consultancy_underweigh_non_neglected_neglect_good,
    consultancy_overweigh_non_neglected,
    consultancy_overweigh_non_neglected_neglect_good,
    consultancy_neglect,
    consultancy_neglect_neglect_good,
    consultancy_neglect_underweigh_non_neglected,
    consultancy_neglect_underweigh_non_neglected_neglect_good,
    consultancy_neglect_overweigh_non_neglected,
    consultancy_neglect_overweigh_non_neglected_neglect_good,
    consultancy_neglect_underweigh_neglected,
    consultancy_neglect_underweigh_neglected_neglect_good,
    consultancy_neglect_overweigh_neglected,
    consultancy_neglect_overweigh_neglected_neglect_good,
    consultancy_neglect_underweigh_both,
    consultancy_neglect_underweigh_both_neglect_good,
    consultancy_neglect_overweigh_both,
    consultancy_neglect_overweigh_both_neglect_good,
    base_canonical,
    base_neglect_good,
    base_underweigh_non_neglected,
    base_underweigh_non_neglected_neglect_good,
    base_overweigh_non_neglected,
    base_overweigh_non_neglected_neglect_good,
    base_neglect,
    base_neglect_neglect_good,
    base_neglect_underweigh_non_neglected,
    base_neglect_underweigh_non_neglected_neglect_good,
    base_neglect_overweigh_non_neglected,
    base_neglect_overweigh_non_neglected_neglect_good,
    base_neglect_underweigh_neglected,
    base_neglect_underweigh_neglected_neglect_good,
    base_neglect_overweigh_neglected,
    base_neglect_overweigh_neglected_neglect_good,
    base_neglect_underweigh_both,
    base_neglect_underweigh_both_neglect_good,
    base_neglect_overweigh_both,
    base_neglect_overweigh_both_neglect_good,
    critiques_canonical,
    critiques_neglect_good,
    critiques_underweigh_non_neglected,
    critiques_underweigh_non_neglected_neglect_good,
    critiques_overweigh_non_neglected,
    critiques_overweigh_non_neglected_neglect_good,
    critiques_neglect,
    critiques_neglect_neglect_good,
    critiques_neglect_underweigh_non_neglected,
    critiques_neglect_underweigh_non_neglected_neglect_good,
    critiques_neglect_overweigh_non_neglected,
    critiques_neglect_overweigh_non_neglected_neglect_good,
    critiques_neglect_underweigh_neglected,
    critiques_neglect_underweigh_neglected_neglect_good,
    critiques_neglect_overweigh_neglected,
    critiques_neglect_overweigh_neglected_neglect_good,
    critiques_neglect_underweigh_both,
    critiques_neglect_underweigh_both_neglect_good,
    critiques_neglect_overweigh_both,
    critiques_neglect_overweigh_both_neglect_good,
]

interesting_overseers = [
    base_canonical,
    base_underweigh_non_neglected,
    base_overweigh_non_neglected,
    base_neglect,
    base_neglect_underweigh_both,
    base_neglect_overweigh_both,
    base_neglect_good,
    consultancy_canonical,
    consultancy_underweigh_non_neglected,
    consultancy_overweigh_non_neglected,
    consultancy_neglect,
    consultancy_neglect_underweigh_both,
    consultancy_neglect_overweigh_both,
    consultancy_neglect_good,
    critiques_canonical,
    critiques_underweigh_non_neglected,
    critiques_overweigh_non_neglected,
    critiques_neglect,
    critiques_neglect_underweigh_both,
    critiques_neglect_overweigh_both,
    critiques_neglect_good,
]

consultancy_canonical.name = 'Consultancy canonical'
consultancy_neglect_good.name = 'Consultancy neglect good'
consultancy_underweigh_non_neglected.name = 'Consultancy underweigh non-neglected'
consultancy_underweigh_non_neglected_neglect_good.name = 'Consultancy underweigh non-neglected neglect good'
consultancy_overweigh_non_neglected.name = 'Consultancy overweigh non-neglected'
consultancy_overweigh_non_neglected_neglect_good.name = 'Consultancy overweigh non-neglected neglect good'
consultancy_neglect.name = 'Consultancy neglect'
consultancy_neglect_neglect_good.name = 'Consultancy neglect neglect good'
consultancy_neglect_underweigh_non_neglected.name = 'Consultancy neglect underweigh non-neglected'
consultancy_neglect_underweigh_non_neglected_neglect_good.name = 'Consultancy neglect underweigh non-neglected neglect good'
consultancy_neglect_overweigh_non_neglected.name = 'Consultancy neglect overweigh non-neglected'
consultancy_neglect_overweigh_non_neglected_neglect_good.name = 'Consultancy neglect overweigh non-neglected neglect good'
consultancy_neglect_underweigh_neglected.name = 'Consultancy neglect underweigh neglected'
consultancy_neglect_underweigh_neglected_neglect_good.name = 'Consultancy neglect underweigh neglected neglect good'
consultancy_neglect_overweigh_neglected.name = 'Consultancy neglect overweigh neglected'
consultancy_neglect_overweigh_neglected_neglect_good.name = 'Consultancy neglect overweigh neglected neglect good'
consultancy_neglect_underweigh_both.name = 'Consultancy neglect underweigh both'
consultancy_neglect_underweigh_both_neglect_good.name = 'Consultancy neglect underweigh both neglect good'
consultancy_neglect_overweigh_both.name = 'Consultancy neglect overweigh both'
consultancy_neglect_overweigh_both_neglect_good.name = 'Consultancy neglect overweigh both neglect good'
base_canonical.name = 'Base canonical'
base_neglect_good.name = 'Base neglect good'
base_underweigh_non_neglected.name = 'Base underweigh non-neglected'
base_underweigh_non_neglected_neglect_good.name = 'Base underweigh non-neglected neglect good'
base_overweigh_non_neglected.name = 'Base overweigh non-neglected'
base_overweigh_non_neglected_neglect_good.name = 'Base overweigh non-neglected neglect good'
base_neglect.name = 'Base neglect'
base_neglect_neglect_good.name = 'Base neglect neglect good'
base_neglect_underweigh_non_neglected.name = 'Base neglect underweigh non-neglected'
base_neglect_underweigh_non_neglected_neglect_good.name = 'Base neglect underweigh non-neglected neglect good'
base_neglect_overweigh_non_neglected.name = 'Base neglect overweigh non-neglected'
base_neglect_overweigh_non_neglected_neglect_good.name = 'Base neglect overweigh non-neglected neglect good'
base_neglect_underweigh_neglected.name = 'Base neglect underweigh neglected'
base_neglect_underweigh_neglected_neglect_good.name = 'Base neglect underweigh neglected neglect good'
base_neglect_overweigh_neglected.name = 'Base neglect overweigh neglected'
base_neglect_overweigh_neglected_neglect_good.name = 'Base neglect overweigh neglected neglect good'
base_neglect_underweigh_both.name = 'Base neglect underweigh both'
base_neglect_underweigh_both_neglect_good.name = 'Base neglect underweigh both neglect good'
base_neglect_overweigh_both.name = 'Base neglect overweigh both'
base_neglect_overweigh_both_neglect_good.name = 'Base neglect overweigh both neglect good'
critiques_canonical.name = 'Critiques canonical'
critiques_neglect_good.name = 'Critiques neglect good'
critiques_underweigh_non_neglected.name = 'Critiques underweigh non-neglected'
critiques_underweigh_non_neglected_neglect_good.name = 'Critiques underweigh non-neglected neglect good'
critiques_overweigh_non_neglected.name = 'Critiques overweigh non-neglected'
critiques_overweigh_non_neglected_neglect_good.name = 'Critiques overweigh non-neglected neglect good'
critiques_neglect.name = 'Critiques neglect'
critiques_neglect_neglect_good.name = 'Critiques neglect neglect good'
critiques_neglect_underweigh_non_neglected.name = 'Critiques neglect underweigh non-neglected'
critiques_neglect_underweigh_non_neglected_neglect_good.name = 'Critiques neglect underweigh non-neglected neglect good'
critiques_neglect_overweigh_non_neglected.name = 'Critiques neglect overweigh non-neglected'
critiques_neglect_overweigh_non_neglected_neglect_good.name = 'Critiques neglect overweigh non-neglected neglect good'
critiques_neglect_underweigh_neglected.name = 'Critiques neglect underweigh neglected'
critiques_neglect_underweigh_neglected_neglect_good.name = 'Critiques neglect underweigh neglected neglect good'
critiques_neglect_overweigh_neglected.name = 'Critiques neglect overweigh neglected'
critiques_neglect_overweigh_neglected_neglect_good.name = 'Critiques neglect overweigh neglected neglect good'
critiques_neglect_underweigh_both.name = 'Critiques neglect underweigh both'
critiques_neglect_underweigh_both_neglect_good.name = 'Critiques neglect underweigh both neglect good'
critiques_neglect_overweigh_both.name = 'Critiques neglect overweigh both'
critiques_neglect_overweigh_both_neglect_good.name = 'Critiques neglect overweigh both neglect good'

fig, consultancy_ax = plt.subplots()

for overseer in interesting_overseers:
    consultancy_ax.plot(overseer.adversarial_alpha, overseer.overseer_mistakes, label=overseer.name)
consultancy_ax.set_xlabel('Adversarial incentive')
consultancy_ax.set_ylabel('Mistake rate')
consultancy_ax.set_title('Mistake rate vs. adversarial incentive')
fig.legend()
fig.tight_layout()

# %%
fig, consultancy_ax = plt.subplots()
colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan', 'magenta', 'yellow', 'black', 'teal', 'coral', 'lightblue', 'lightgreen', 'lavender', 'salmon', 'darkred']
for overseer, color in zip(interesting_overseers, colors):
    consultancy_ax.plot(overseer.adversarial_alpha, overseer.mean_expected_score, label=None, color=color, linestyle='--')
    consultancy_ax.plot(overseer.adversarial_alpha, overseer.mean_ground_truth_score, label=overseer.name, color=color)
    # ax.plot(overseer.adversarial_alpha, canonical.mean_expected_score, label='Canonical', linestyle='--')
    consultancy_ax.set_xlabel('Adversarial incentive')
    consultancy_ax.set_ylabel('Mean score')
    consultancy_ax.set_title(f'Mean score vs. adversarial incentive ({overseer.name})')

fig.legend(loc='lower left', bbox_to_anchor=(0.09, 0.13))
fig.tight_layout()

# %%
from matplotlib.ticker import FuncFormatter

def percentage_formatter(x, pos):
    return f'{100 * x:.0f}%'

percent_formatter = FuncFormatter(percentage_formatter)

fig, axs = plt.subplots(5, 3, figsize=(15, 20))

twins = []

axs[0, 0].plot(base_neglect.adversarial_alpha, base_neglect.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[0, 0].twinx()
twin.plot(base_neglect.adversarial_alpha, base_neglect.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[0, 1].plot(consultancy_neglect.adversarial_alpha, consultancy_neglect.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[0, 1].twinx()
twin.plot(consultancy_neglect.adversarial_alpha, consultancy_neglect.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[0, 2].plot(critiques_neglect.adversarial_alpha, critiques_neglect.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[0, 2].twinx()
twin.plot(critiques_neglect.adversarial_alpha, critiques_neglect.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[1, 0].plot(base_neglect_good.adversarial_alpha, base_neglect_good.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[1, 0].twinx()
twin.plot(base_neglect_good.adversarial_alpha, base_neglect_good.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[1, 1].plot(consultancy_neglect_good.adversarial_alpha, consultancy_neglect_good.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[1, 1].twinx()
twin.plot(consultancy_neglect_good.adversarial_alpha, consultancy_neglect_good.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[1, 2].plot(critiques_neglect_good.adversarial_alpha, critiques_neglect_good.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[1, 2].twinx()
twin.plot(critiques_neglect_good.adversarial_alpha, critiques_neglect_good.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[2, 0].plot(base_underweigh_non_neglected.adversarial_alpha, base_underweigh_non_neglected.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[2, 0].twinx()
twin.plot(base_underweigh_non_neglected.adversarial_alpha, base_underweigh_non_neglected.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[2, 1].plot(consultancy_underweigh_non_neglected.adversarial_alpha, consultancy_underweigh_non_neglected.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[2, 1].twinx()
twin.plot(consultancy_underweigh_non_neglected.adversarial_alpha, consultancy_underweigh_non_neglected.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[2, 2].plot(critiques_underweigh_non_neglected.adversarial_alpha, critiques_underweigh_non_neglected.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[2, 2].twinx()
twin.plot(critiques_underweigh_non_neglected.adversarial_alpha, critiques_underweigh_non_neglected.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[3, 0].plot(base_overweigh_non_neglected.adversarial_alpha, base_overweigh_non_neglected.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[3, 0].twinx()
twin.plot(base_overweigh_non_neglected.adversarial_alpha, base_overweigh_non_neglected.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[3, 1].plot(consultancy_overweigh_non_neglected.adversarial_alpha, consultancy_overweigh_non_neglected.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[3, 1].twinx()
twin.plot(consultancy_overweigh_non_neglected.adversarial_alpha, consultancy_overweigh_non_neglected.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[3, 2].plot(critiques_overweigh_non_neglected.adversarial_alpha, critiques_overweigh_non_neglected.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[3, 2].twinx()
twin.plot(critiques_overweigh_non_neglected.adversarial_alpha, critiques_overweigh_non_neglected.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[4, 0].plot(base_neglect_overweigh_both.adversarial_alpha, base_neglect_overweigh_both.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[4, 0].twinx()
twin.plot(base_neglect_overweigh_both.adversarial_alpha, base_neglect_overweigh_both.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[4, 1].plot(consultancy_neglect_overweigh_both.adversarial_alpha, consultancy_neglect_overweigh_both.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[4, 1].twinx()
twin.plot(consultancy_neglect_overweigh_both.adversarial_alpha, consultancy_neglect_overweigh_both.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

axs[4, 2].plot(critiques_neglect_overweigh_both.adversarial_alpha, critiques_neglect_overweigh_both.overseer_accuracy, color='blue', label='Accuracy')
twin = axs[4, 2].twinx()
twin.plot(critiques_neglect_overweigh_both.adversarial_alpha, critiques_neglect_overweigh_both.mean_ground_truth_score, color='orange', label='Mean score')
twins.append(twin)

for ax in axs.flat:
    ax.yaxis.set_major_formatter(percent_formatter)
    ax.set_ylim(0, 1.1)
    ax.set_ylabel('Overseer Accuracy', color='blue')
    ax.tick_params(axis='y', labelcolor='blue')
    ax.set_xlabel('Adversarial incentive')

for twin in twins:
    twin.set_ylim(1, 8)
    twin.set_ylabel('Mean True Score', color='orange')
    twin.tick_params(axis='y', labelcolor='orange')

# Set column titles
fig.text(0.24, 0.94, 'Base', ha='center', va='center', fontsize=12, fontweight='bold')
fig.text(0.54, 0.94, 'Consultancy', ha='center', va='center', fontsize=12, fontweight='bold')
fig.text(0.85, 0.94, 'Critiques', ha='center', va='center', fontsize=12, fontweight='bold')


# Set row titles
fig.text(0.07, 0.85, 'Neglect', ha='center', va='center', rotation='vertical', fontsize=12, fontweight='bold')
fig.text(0.07, 0.67, 'Lazy', ha='center', va='center', rotation='vertical', fontsize=12, fontweight='bold')
fig.text(0.07, 0.48, 'Underweigh', ha='center', va='center', rotation='vertical', fontsize=12, fontweight='bold')
fig.text(0.07, 0.28, 'Overweigh', ha='center', va='center', rotation='vertical', fontsize=12, fontweight='bold')
fig.text(0.07, 0.11, 'Neglect bad + Double Overweigh', ha='center', va='center', rotation='vertical', fontsize=12, fontweight='bold')

# Adjust layout and display the plot
fig.tight_layout(rect=(0.08, 0.0, 1.0, 0.94))

# %%
from pathlib import Path
from codenames_oversight.oversight import PreferenceSet

ppo_data = [PreferenceSet.model_validate_json(line).oversights[0].model_dump() for line in Path("job_outputs/codenames_oversight_ppo_small_robust_init_ratio/48875882_7.out").read_text().splitlines()]

ppo_df = pd.DataFrame(ppo_data)

fig, consultancy_ax = plt.subplots()
consultancy_ax.plot(ppo_df.expected_score.rolling(window=512).mean(), label='Overseer')
consultancy_ax.plot(ppo_df.ground_truth_score.rolling(window=512).mean(), label='Ground truth')
consultancy_ax.plot(ppo_df.valid_targets.apply(len).rolling(window=512).mean(), label='N targets', linestyle='--')
consultancy_ax.set_xlabel('Sample')
consultancy_ax.set_ylabel('Score')
consultancy_ax.set_title('Score vs. sample (smoothed)')
fig.legend()
fig.tight_layout()

# %%
consultancy_neglect
# Out:
#       overseer__name  overseer__neglect_words  overseer__bias_neglected_words  \
# 50  negligent_biased                        1                               0
# 51  negligent_biased                        1                               0
# 52  negligent_biased                        1                               0
# 53  negligent_biased                        1                               0
# 54  negligent_biased                        1                               0
# 55  negligent_biased                        1                               0
# 56  negligent_biased                        1                               0
# 57  negligent_biased                        1                               0
# 58  negligent_biased                        1                               0
# 59  negligent_biased                        1                               0
#
#     overseer__bias_non_neglected_words  overseer__bias_factor  \
# ...
